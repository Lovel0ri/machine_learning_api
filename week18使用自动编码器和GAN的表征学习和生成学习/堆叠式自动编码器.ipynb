# %%
import keras
stacked_encoder = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28,28]),
    keras.layers.Dense(100,activation="selu"),
    keras.layers.Dense(30,activation="selu")
])

stacked_decoder = keras.models.Sequential([
    keras.layers.Dense(100,activation="selu",input_shape=[30]),
    keras.layers.Dense(28*28,activation="sigmoid"),
    keras.layers.Reshape([28,28])    
])
stacked_ae = keras.models.Sequential([stacked_encoder,stacked_decoder])

# %%
stacked_ae.compile(loss="binary_crossentropy",
                   optimizer=keras.optimizers.SGD(learning_rate=0.1))

# %%
import numpy as np

# 生成随机3D数据点
X= np.random.rand(1000,28,28)
X_train_size = int(0.8*int(len(X)))
X_train_size
X_train = X[:X_train_size]
X_valid = X[X_train_size:]

# %%
stacked_ae.fit(X_train,X_train,epochs=10,validation_data=[X_valid,X_valid ])
# Out:
# Epoch 1/10
# 25/25 [==============================] - 1s 16ms/step - loss: 0.7039 - val_loss: 0.7019
# Epoch 2/10
# 25/25 [==============================] - 0s 9ms/step - loss: 0.7011 - val_loss: 0.7007
# Epoch 3/10
# 25/25 [==============================] - 0s 6ms/step - loss: 0.7002 - val_loss: 0.7001
# Epoch 4/10
# 25/25 [==============================] - 0s 7ms/step - loss: 0.6997 - val_loss: 0.6998
# Epoch 5/10
# 25/25 [==============================] - 0s 7ms/step - loss: 0.6994 - val_loss: 0.6996
# Epoch 6/10
# 25/25 [==============================] - 0s 7ms/step - loss: 0.6992 - val_loss: 0.6994
# Epoch 7/10
# 25/25 [==============================] - 0s 8ms/step - loss: 0.6991 - val_loss: 0.6993
# Epoch 8/10
# 25/25 [==============================] - 0s 7ms/step - loss: 0.6989 - val_loss: 0.6992
# Epoch 9/10
# 25/25 [==============================] - 0s 8ms/step - loss: 0.6988 - val_loss: 0.6991
# Epoch 10/10
# 25/25 [==============================] - 0s 7ms/step - loss: 0.6987 - val_loss: 0.6990

# %%
from sklearn.manifold import TSNE
