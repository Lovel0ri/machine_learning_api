# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 46.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 27.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 130.4 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install --upgrade accelerate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.1/219.1 kB 5.9 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/Lovel0ri/NLP-practice-with-Tensorflow2.git
# Out:
# Cloning into 'NLP-practice-with-Tensorflow2'...
# remote: Enumerating objects: 141, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 141 (delta 12), reused 22 (delta 5), pack-reused 110
# Receiving objects: 100% (141/141), 387.05 MiB | 49.29 MiB/s, done.
# Resolving deltas: 100% (56/56), done.
# Updating files: 100% (53/53), done.
